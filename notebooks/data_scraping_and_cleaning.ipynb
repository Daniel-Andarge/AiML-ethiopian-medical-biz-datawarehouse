# %% [markdown]
# # Data Scraping and Cleaning pipeline

# %%
import sys
import os
sys.path.append('../scripts')
from load_csv import *
from data_cleaning_and_saving import *

# %%
# path to the CSV file
filename = 'Doctors Ethiopia.csv'
path = os.path.join('..', 'data/raw', filename)

# Load dataset
raw_df = load_data(path)

# %% [markdown]
# ## Data scraping and collection pipeline

# %% [markdown]
# ### Doctors Ethiopia Data|

# %%
raw_df.head()
# Out:
#             channel  message_id  \
# 0  Doctors Ethiopia         864
# 1  Doctors Ethiopia         863
# 2  Doctors Ethiopia         862
# 3  Doctors Ethiopia         861
# 4  Doctors Ethiopia         860
#
#                                              content  \
# 0  https://youtu.be/5DBoEm-8kmA?si=LDLuEecNfULJVD...
# 1  ዶክተርስ ኢትዮጵያ በ አዲስ አቀራረብ በ ቴሌቪዥን ፕሮግራሙን ለመጀመር ከ...
# 2  ሞት በስኳር \n\nለልጆቻችን የምናሲዘው ምሳቃ ሳናቀው እድሚያቸውን ይቀን...
# 3  ከ HIV የተፈወሰ ሰው አጋጥሟችሁ ያቃል ? ፈውስ እና ህክምና ?\n\nሙ...
# 4  በቅርብ ጊዜ በሃገራችን ላይ እየተስተዋለ ያለ የተመሳሳይ ፆታ ( Homos...
#
#                    timestamp    views                message_link
# 0  2023-12-18 17:04:02+00:00   5730.0  https://t.me/DoctorsET/864
# 1  2023-11-03 16:14:39+00:00   8420.0  https://t.me/DoctorsET/863
# 2  2023-10-02 16:37:39+00:00  10878.0  https://t.me/DoctorsET/862
# 3  2023-09-16 07:54:32+00:00  11298.0  https://t.me/DoctorsET/861
# 4  2023-09-01 16:16:15+00:00  13106.0  https://t.me/DoctorsET/860

# %% [markdown]
# ### ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEALTH CONSULTANCY CENTER

# %%
raw_df_ethio.head()
# Out:
#                                              channel  message_id  \
# 0  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...        2156
# 1  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...        2155
# 2  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...        2154
# 3  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...        2152
# 4  ETHIO-AMERICAN MEDICAL TRAININGS( CPD ) & HEAL...        2151
#
#                                              content  \
# 0  💥የሞያ ፈቃድ በቅርቡ ለምታሳድሱ💥               \n\n#CPD_(...
# 1                                                NaN
# 2  #💥የግርዛት_ስልጠና_Addis_Ababa & nekemte\n#Circumcis...
# 3  #💥የግርዛት_ስልጠና_Addis_Ababa\n#Circumcision_Skill_...
# 4  #💥የግርዛት_ስልጠና_Addis_Ababa\n#Circumcision_Skill_...
#
#                    timestamp   views             message_link
# 0  2024-06-12 05:44:23+00:00   665.0  https://t.me/EAHCI/2156
# 1  2024-06-11 17:26:32+00:00  1731.0  https://t.me/EAHCI/2155
# 2  2024-06-11 17:26:32+00:00  1577.0  https://t.me/EAHCI/2154
# ...

# %% [markdown]
# ### Lobelia pharmacy and cosmetics

# %%
raw_df_lobe.head()
# Out:
#                           channel  message_id  \
# 0  Lobelia pharmacy and cosmetics        9437
# 1  Lobelia pharmacy and cosmetics        9436
# 2  Lobelia pharmacy and cosmetics        9435
# 3  Lobelia pharmacy and cosmetics        9434
# 4  Lobelia pharmacy and cosmetics        9433
#
#                                              content  \
# 0  CENTRUM ADULT 50+ 200 GUMMIES \nPrice 5700 bir...
# 1  OMEGA 3 200 SOFTGELS \nPrice 5000 birr \nTeleg...
# 2  OMEGA 3,6,9 150 SOFTGELS \nPrice 5000 birr \nT...
# 3  CENTRUM MEN 50+\nPrice 5700 birr \nTelegram ht...
# 4  CENTRUM WOMEN 50+\nPrice 5700 birr \nTelegram ...
#
#                    timestamp  views                         message_link
# 0  2024-06-12 08:36:35+00:00   1073  https://t.me/lobelia4cosmetics/9437
# 1  2024-06-12 08:32:43+00:00    981  https://t.me/lobelia4cosmetics/9436
# 2  2024-06-12 08:31:20+00:00    762  https://t.me/lobelia4cosmetics/9435
# ...

# %% [markdown]
# ### የጤና ወግ - የጤና መረጃ

# %%
raw_df_yetene.head()
# Out:
#             channel  message_id  \
# 0  የጤና ወግ - የጤና መረጃ        1083
# 1  የጤና ወግ - የጤና መረጃ        1082
# 2  የጤና ወግ - የጤና መረጃ        1081
# 3  የጤና ወግ - የጤና መረጃ        1080
# 4  የጤና ወግ - የጤና መረጃ        1079
#
#                                              content  \
# 0                                                NaN
# 1                                       ጥያቄያችሁን አጋሩን
# 2  https://t.me/yetenaweg?livestream\n\nስለ ኩላሊት ጤ...
# 3                                                NaN
# 4                                                NaN
#
#                    timestamp   views                 message_link
# 0  2024-06-09 16:36:21+00:00     NaN  https://t.me/yetenaweg/1083
# 1  2024-06-09 15:28:37+00:00   849.0  https://t.me/yetenaweg/1082
# 2  2024-06-09 15:05:18+00:00   862.0  https://t.me/yetenaweg/1081
# 3  2024-06-09 15:01:25+00:00     NaN  https://t.me/yetenaweg/1080
# 4  2024-06-06 07:51:31+00:00  1348.0  https://t.me/yetenaweg/1079

# %% [markdown]
# ## Data Cleaning pipeline

# %%
# %run ../scripts/data_cleaning_and_saving.py

# %% [markdown]
# ### Load Cleaned and Transformed Dataset

# %%
# path to the CSV file
filename = 'cleaned_data.csv'
path = os.path.join('..', 'data/processed', filename)

# Load dataset
cleaned_df = load_data(path)

# %%
cleaned_df
# Out:
#               channel  message_id  \
# 0    Doctors Ethiopia         864
# 1    Doctors Ethiopia         863
# 2    Doctors Ethiopia         862
# 3    Doctors Ethiopia         861
# 4    Doctors Ethiopia         860
# ..                ...         ...
# 355  የጤና ወግ - የጤና መረጃ         981
# 356  የጤና ወግ - የጤና መረጃ         980
# 357  የጤና ወግ - የጤና መረጃ         979
# 358  የጤና ወግ - የጤና መረጃ         978
# 359  የጤና ወግ - የጤና መረጃ         977
#
#                                                content  \
# 0    httpsyoutube5dboem8kmasildlueecnfuljvdzl   \n\...
# 1    ዶክተርስ ኢትዮጵያ በ አዲስ አቀራረብ በ ቴሌቪዥን ፕሮግራሙን ለመጀመር ከ...
# 2    ሞት በስኳር \n\nለልጆቻችን የምናሲዘው ምሳቃ ሳናቀው እድሚያቸውን ይቀን...
# 3    ከ hiv የተፈወሰ ሰው አጋጥሟችሁ ያቃል  ፈውስ እና ህክምና \n\nሙሉ ...
# 4    በቅርብ ጊዜ በሃገራችን ላይ እየተስተዋለ ያለ የተመሳሳይ ፆታ  homose...
# ..                                                 ...
# 355                       ከተወሰኑ ደቂቃዎች በሗላ ውይይታችን ይጀመራል
# 356                                  message not found
# ...

# %%
cleaned_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   channel       360 non-null    object
#  1   message_id    360 non-null    int64
#  2   content       360 non-null    object
#  3   timestamp     360 non-null    object
#  4   views         360 non-null    float64
#  5   message_link  360 non-null    object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 17.0+ KB
